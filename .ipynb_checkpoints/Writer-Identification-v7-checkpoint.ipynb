# %% [markdown]
# # Build a writer identifier using a handwriting recognition model
# Changing epoch number

# %%
# !pip install numpy
# !pip install opencv-python
# !pip install matplotlib
# !pip install tensorflow
# !pip install scikit-learn
# !pip install keras-tuner

# %% [markdown]
# ## Import Libraries

# %%
import os
import cv2
import numpy as np
# import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16856\448977632.py:12: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %% [markdown]
# ## Load Dataset
# ### Folder Organisation Level
# Resized-Datasets
# <pre>
#     1
#         450 handwriting samples written by Janice
# </pre>
# <pre>
#     2
#         450 handwriting samples written by Jasmine
# </pre>

# %%
# Set the path to our handwriting dataset
dataset_dir = 'Resized-Datasets'

images = []
labels = []

# Each subdirectory in the dataset directory corresponds to a different writer
for writer_dir in os.listdir(dataset_dir):
    writer_images = []
    writer_labels = []
    writer_path = os.path.join(dataset_dir, writer_dir)
#     print("writer_path: ", writer_path)
    
    # Each image file in the writer directory corresponds to a handwriting sample
    for image_file in os.listdir(writer_path):
        image_path = os.path.join(writer_path, image_file)
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        writer_images.append(img)
        writer_labels.append(int(writer_dir))
    
    # images += writer_images
    images.extend(writer_images)
    labels.extend(writer_labels)

# Load the handwriting data 
# Convert the lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Data Preparation

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Preprocess the images
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255.0
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255.0

# Encode the labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Determine the number of unique labels in our dataset
num_classes = len(label_encoder.classes_)

# Convert the labels to one-hot encoding
y_train = to_categorical(y_train_encoded, num_classes=num_classes)
y_test = to_categorical(y_test_encoded, num_classes=num_classes)

# %% [markdown]
# ## Model Building
# Find the best hyperparameters that results the highest accuracy using iterative for-loop and tuner and save the model.

# %% [markdown]
# ### epoch number = 5

# %%
best_accuracy = 0.0
best_hyperparametes = None

for i in range(10):
    
    
    def build_model(hp):
    
        model = keras.Sequential()
    
        # Convolutional layer
        model.add(keras.layers.Conv2D(
            filters=hp.Int('conv_filters', min_value=16, max_value=128, step=16),
            kernel_size=(3, 3),
            activation='relu',
            input_shape=(28, 28, 1)
        ))
        model.add(keras.layers.BatchNormalization())
        model.add(keras.layers.MaxPooling2D((2, 2)))

        # Flatten the output from the convolutional layer
        model.add(keras.layers.Flatten())
    
        # Dense hidden layer
        model.add(keras.layers.Dense(
            units=hp.Int('dense_units', min_value=64, max_value=256, step=64),
            activation='relu'
        ))
        model.add(keras.layers.Dropout(0.5))

        # Dense output layer
        model.add(keras.layers.Dense(num_classes, activation='softmax'))
    
        # Compile the model
        model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
        return model

    # Perform hyperparameter search
    tuner = RandomSearch(
        build_model,
        objective='val_accuracy',
        max_trials=10,
        directory='tuner_directory',
        project_name='writer_identification'
    )

    tuner.search(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

    # Get the best hyperparameters
    best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
    best_model = tuner.hypermodel.build(best_hp)

    # Train the best model
    best_model.fit(X_train, y_train, epochs=5, validation_data=(X_test, y_test))
        
    loss, accuracy = best_model.evaluate(X_test, y_test)
    print('Test accuracy:', accuracy)
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_hyperparameters = best_hp
        # Save the trained model
        best_model.save('writerIdentifier_v7_model.h5')
        

# Save the best hyperparameters
with open('bh_v7_model.txt', 'w') as f:
    f.write(str(best_hyperparameters.values))
    
print("Best accuracy:", best_accuracy)
print("Best hyperparameters:", best_hyperparameters.values)
# Out:
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 5s 89ms/step - loss: 0.5803 - accuracy: 0.7083 - val_loss: 0.8222 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 72ms/step - loss: 0.3832 - accuracy: 0.8264 - val_loss: 0.9829 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 73ms/step - loss: 0.3280 - accuracy: 0.8611 - val_loss: 0.6815 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 76ms/step - loss: 0.2499 - accuracy: 0.9014 - val_loss: 0.6495 - val_accuracy: 0.5111
# Epoch 5/5
# 23/23 [==============================] - 2s 72ms/step - loss: 0.2006 - accuracy: 0.9181 - val_loss: 0.6114 - val_accuracy: 0.7611
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6114 - accuracy: 0.7611
# Test accuracy: 0.7611111402511597
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 4s 108ms/step - loss: 0.5965 - accuracy: 0.6819 - val_loss: 0.7892 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 75ms/step - loss: 0.3790 - accuracy: 0.8333 - val_loss: 0.8991 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 79ms/step - loss: 0.3481 - accuracy: 0.8389 - val_loss: 0.7433 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 80ms/step - loss: 0.2738 - accuracy: 0.8889 - val_loss: 0.7485 - val_accuracy: 0.4778
# Epoch 5/5
# 23/23 [==============================] - 2s 80ms/step - loss: 0.2297 - accuracy: 0.9056 - val_loss: 0.6553 - val_accuracy: 0.4944
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6553 - accuracy: 0.4944
# Test accuracy: 0.49444442987442017
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 3s 87ms/step - loss: 0.6008 - accuracy: 0.7139 - val_loss: 0.8697 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 74ms/step - loss: 0.3952 - accuracy: 0.8194 - val_loss: 0.9459 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 76ms/step - loss: 0.3387 - accuracy: 0.8597 - val_loss: 0.6735 - val_accuracy: 0.4833
# Epoch 4/5
# 23/23 [==============================] - 2s 74ms/step - loss: 0.2506 - accuracy: 0.9042 - val_loss: 0.6672 - val_accuracy: 0.4833
# Epoch 5/5
# 23/23 [==============================] - 2s 77ms/step - loss: 0.2090 - accuracy: 0.9278 - val_loss: 0.7513 - val_accuracy: 0.4778
# 6/6 [==============================] - 0s 13ms/step - loss: 0.7513 - accuracy: 0.4778
# Test accuracy: 0.47777777910232544
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 3s 84ms/step - loss: 0.6444 - accuracy: 0.6611 - val_loss: 0.9062 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 76ms/step - loss: 0.4122 - accuracy: 0.8000 - val_loss: 1.0896 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 74ms/step - loss: 0.3170 - accuracy: 0.8583 - val_loss: 0.9677 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 75ms/step - loss: 0.3080 - accuracy: 0.8542 - val_loss: 0.7313 - val_accuracy: 0.4778
# Epoch 5/5
# 23/23 [==============================] - 2s 74ms/step - loss: 0.2435 - accuracy: 0.8958 - val_loss: 0.7551 - val_accuracy: 0.4778
# 6/6 [==============================] - 0s 13ms/step - loss: 0.7551 - accuracy: 0.4778
# Test accuracy: 0.47777777910232544
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 3s 84ms/step - loss: 0.6381 - accuracy: 0.6681 - val_loss: 0.8872 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 75ms/step - loss: 0.4173 - accuracy: 0.8181 - val_loss: 1.2951 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 75ms/step - loss: 0.3281 - accuracy: 0.8639 - val_loss: 0.8246 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 75ms/step - loss: 0.2703 - accuracy: 0.8819 - val_loss: 0.8498 - val_accuracy: 0.4778
# Epoch 5/5
# 23/23 [==============================] - 2s 76ms/step - loss: 0.2271 - accuracy: 0.9153 - val_loss: 0.7750 - val_accuracy: 0.4778
# 6/6 [==============================] - 0s 18ms/step - loss: 0.7750 - accuracy: 0.4778
# Test accuracy: 0.47777777910232544
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 3s 90ms/step - loss: 0.7080 - accuracy: 0.6458 - val_loss: 0.8414 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 74ms/step - loss: 0.4683 - accuracy: 0.7653 - val_loss: 0.8311 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 75ms/step - loss: 0.3706 - accuracy: 0.8361 - val_loss: 0.8819 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 73ms/step - loss: 0.3136 - accuracy: 0.8667 - val_loss: 0.9089 - val_accuracy: 0.4778
# Epoch 5/5
# 23/23 [==============================] - 2s 72ms/step - loss: 0.2625 - accuracy: 0.8958 - val_loss: 0.6825 - val_accuracy: 0.4778
# 6/6 [==============================] - 0s 18ms/step - loss: 0.6825 - accuracy: 0.4778
# Test accuracy: 0.47777777910232544
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 3s 89ms/step - loss: 0.5844 - accuracy: 0.6986 - val_loss: 0.9265 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 73ms/step - loss: 0.3974 - accuracy: 0.8222 - val_loss: 1.2046 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 73ms/step - loss: 0.2992 - accuracy: 0.8694 - val_loss: 0.8729 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 77ms/step - loss: 0.2475 - accuracy: 0.8944 - val_loss: 0.7432 - val_accuracy: 0.4778
# Epoch 5/5
# 23/23 [==============================] - 2s 77ms/step - loss: 0.1886 - accuracy: 0.9264 - val_loss: 0.7909 - val_accuracy: 0.4778
# 6/6 [==============================] - 0s 11ms/step - loss: 0.7909 - accuracy: 0.4778
# Test accuracy: 0.47777777910232544
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 3s 84ms/step - loss: 0.6656 - accuracy: 0.6667 - val_loss: 0.9342 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 74ms/step - loss: 0.4115 - accuracy: 0.8000 - val_loss: 0.8508 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 77ms/step - loss: 0.3015 - accuracy: 0.8708 - val_loss: 0.8569 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 93ms/step - loss: 0.2426 - accuracy: 0.8972 - val_loss: 0.8373 - val_accuracy: 0.4778
# Epoch 5/5
# 23/23 [==============================] - 2s 74ms/step - loss: 0.2067 - accuracy: 0.9153 - val_loss: 0.7240 - val_accuracy: 0.4778
# 6/6 [==============================] - 0s 16ms/step - loss: 0.7240 - accuracy: 0.4778
# Test accuracy: 0.47777777910232544
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 4s 95ms/step - loss: 0.6318 - accuracy: 0.6694 - val_loss: 0.8123 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 75ms/step - loss: 0.4137 - accuracy: 0.7986 - val_loss: 0.9122 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 84ms/step - loss: 0.3414 - accuracy: 0.8375 - val_loss: 0.7547 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 78ms/step - loss: 0.2781 - accuracy: 0.8903 - val_loss: 0.7618 - val_accuracy: 0.4778
# Epoch 5/5
# 23/23 [==============================] - 2s 75ms/step - loss: 0.2201 - accuracy: 0.9167 - val_loss: 0.6748 - val_accuracy: 0.4833
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6748 - accuracy: 0.4833
# Test accuracy: 0.4833333194255829
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/5
# 23/23 [==============================] - 3s 92ms/step - loss: 0.6110 - accuracy: 0.6667 - val_loss: 0.9235 - val_accuracy: 0.4778
# Epoch 2/5
# 23/23 [==============================] - 2s 78ms/step - loss: 0.4193 - accuracy: 0.7958 - val_loss: 1.0303 - val_accuracy: 0.4778
# Epoch 3/5
# 23/23 [==============================] - 2s 77ms/step - loss: 0.3646 - accuracy: 0.8347 - val_loss: 0.7937 - val_accuracy: 0.4778
# Epoch 4/5
# 23/23 [==============================] - 2s 81ms/step - loss: 0.3001 - accuracy: 0.8819 - val_loss: 0.7641 - val_accuracy: 0.4778
# Epoch 5/5
# 23/23 [==============================] - 2s 80ms/step - loss: 0.2506 - accuracy: 0.9056 - val_loss: 0.7098 - val_accuracy: 0.4778
# 6/6 [==============================] - 0s 14ms/step - loss: 0.7098 - accuracy: 0.4778
# Test accuracy: 0.47777777910232544
# Best accuracy: 0.7611111402511597
# Best hyperparameters: {'conv_filters': 64, 'dense_units': 128}

# %%
best_accuracy = 0.0
best_hyperparametes = None

for i in range(10):
    
    
    def build_model(hp):
    
        model = keras.Sequential()
    
        # Convolutional layer
        model.add(keras.layers.Conv2D(
            filters=hp.Int('conv_filters', min_value=16, max_value=128, step=16),
            kernel_size=(3, 3),
            activation='relu',
            input_shape=(28, 28, 1)
        ))
        model.add(keras.layers.BatchNormalization())
        model.add(keras.layers.MaxPooling2D((2, 2)))

        # Flatten the output from the convolutional layer
        model.add(keras.layers.Flatten())
    
        # Dense hidden layer
        model.add(keras.layers.Dense(
            units=hp.Int('dense_units', min_value=64, max_value=256, step=64),
            activation='relu'
        ))
        model.add(keras.layers.Dropout(0.5))

        # Dense output layer
        model.add(keras.layers.Dense(num_classes, activation='softmax'))
    
        # Compile the model
        model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
        return model

    # Perform hyperparameter search
    tuner = RandomSearch(
        build_model,
        objective='val_accuracy',
        max_trials=10,
        directory='tuner_directory',
        project_name='writer_identification'
    )

    tuner.search(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

    # Get the best hyperparameters
    best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
    best_model = tuner.hypermodel.build(best_hp)

    # Train the best model
    best_model.fit(X_train, y_train, epochs=15, validation_data=(X_test, y_test))
        
    loss, accuracy = best_model.evaluate(X_test, y_test)
    print('Test accuracy:', accuracy)
    
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_hyperparameters = best_hp
        # Save the trained model
        best_model.save('writerIdentifier_v7_model_ep15.h5')
        

# Save the best hyperparameters
with open('bh_v7_model_ep15.txt', 'w') as f:
    f.write(str(best_hyperparameters.values))
    
print("Best accuracy:", best_accuracy)
print("Best hyperparameters:", best_hyperparameters.values)

# %% [markdown]
# ## Model Evaluation
# Evaluate the trained model with the best accuracy using test data.

# %%
# Load the saved model with the highest validation accuracy
best_model = keras.models.load_model('writerIdentifier_v7_model.h5')

# Evaluate the best model
loss, accuracy = best_model.evaluate(X_test, y_test)
print('Loss:', loss)
print('Test accuracy:', accuracy)

# Load the saved model with the highest validation accuracy
best_model = keras.models.load_model('writerIdentifier_v7_model_ep15.h5')

# Evaluate the best model
loss, accuracy = best_model.evaluate(X_test, y_test)
print('Loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6114 - accuracy: 0.7611
# Loss: 0.6113780736923218
# Test accuracy: 0.7611111402511597
