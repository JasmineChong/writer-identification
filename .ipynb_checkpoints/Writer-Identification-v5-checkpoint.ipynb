# %% [markdown]
# # Build a writer identifier using a handwriting recognition model

# %%
# !pip install numpy
# !pip install opencv-python
# !pip install matplotlib
# !pip install tensorflow
# !pip install scikit-learn
# !pip install keras-tuner

# %% [markdown]
# ## Import Libraries

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
# Out:
# C:\Users\Janice\AppData\Local\Temp\ipykernel_31588\774798532.py:12: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import RandomSearch

# %% [markdown]
# ## Load Dataset
# ### Folder Organisation Level
# Resized-Datasets
# <pre>
#     1
#         450 handwriting samples written by Janice
# </pre>
# <pre>
#     2
#         450 handwriting samples written by Jasmine
# </pre>

# %%
# Set the path to our handwriting dataset
dataset_dir = 'Resized-Datasets'

images = []
labels = []

# Each subdirectory in the dataset directory corresponds to a different writer
for writer_dir in os.listdir(dataset_dir):
    writer_images = []
    writer_labels = []
    writer_path = os.path.join(dataset_dir, writer_dir)
#     print("writer_path: ", writer_path)
    
    # Each image file in the writer directory corresponds to a handwriting sample
    for image_file in os.listdir(writer_path):
        image_path = os.path.join(writer_path, image_file)
        img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        writer_images.append(img)
        writer_labels.append(int(writer_dir))
    
    # images += writer_images
    images.extend(writer_images)
    labels.extend(writer_labels)

# Load the handwriting data 
# Convert the lists to numpy arrays
images = np.array(images)
labels = np.array(labels)

# %%
np.random.seed(42)
tf.random.set_seed(42)

# %% [markdown]
# ## Data Preparation

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=42)

# Preprocess the images
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255.0
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255.0

# Encode the labels
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# Determine the number of unique labels in our dataset
num_classes = len(label_encoder.classes_)

# Convert the labels to one-hot encoding
y_train = to_categorical(y_train_encoded, num_classes=num_classes)
y_test = to_categorical(y_test_encoded, num_classes=num_classes)

# %% [markdown]
# ## Model Building
# Find the best hyperparameters that results the highest accuracy using iterative for-loop and tuner and save the model.

# %%
from tf_explain.callbacks.activations_visualization import ActivationsVisualizationCallback

# %%
best_accuracy = 0.0
best_hyperparametes = None
best_run_num = 0

for i in range(10):
    
    
    def build_model(hp):
    
        model = keras.Sequential()
    
        # Convolutional layer
        model.add(keras.layers.Conv2D(
            filters=hp.Int('conv_filters', min_value=16, max_value=128, step=16),
            kernel_size=(3, 3),
            activation='relu',
            input_shape=(28, 28, 1),
            name='visualization_layer'
        ))
        model.add(keras.layers.BatchNormalization())
        model.add(keras.layers.MaxPooling2D((2, 2)))

        # Flatten the output from the convolutional layer
        model.add(keras.layers.Flatten())
    
        # Dense hidden layer
        model.add(keras.layers.Dense(
            units=hp.Int('dense_units', min_value=64, max_value=256, step=64),
            activation='relu'
        ))
        model.add(keras.layers.Dropout(0.5))

        # Dense output layer
        model.add(keras.layers.Dense(num_classes, activation='softmax'))
    
        # Compile the model
        model.compile(optimizer='adam',
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])
    
        return model

    # Perform hyperparameter search
    tuner = RandomSearch(
        build_model,
        objective='val_accuracy',
        max_trials=10,
        directory='tuner_directory',
        project_name='writer_identification'
    )

    tuner.search(X_train, y_train, epochs=10, validation_data=(X_test, y_test))

    # Get the best hyperparameters
    best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
    best_model = tuner.hypermodel.build(best_hp)
    
    # Define the Activation Visualization callback
    output_dir = './visualizations'
    callbacks = [
        ActivationsVisualizationCallback(
            validation_data=(X_test, y_test),
            layers_name=['visualization_layer'],
            output_dir=output_dir,
        ),
    ]

    # Train the best model
    best_model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test
# Epoch 8/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.1480 - accuracy: 0.95
# 23/23 [==============================] - 1s 58ms/step - loss: 0.1540 - accuracy: 0.9514 - val_loss: 0.7939 - val_accuracy: 0.4833
# Epoch 9/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.1144 - accuracy: 0.96
# 23/23 [==============================] - 1s 58ms/step - loss: 0.1162 - accuracy: 0.9583 - val_loss: 0.6130 - val_accuracy: 0.5778
# Epoch 10/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.1159 - accuracy: 0.95
# 23/23 [==============================] - 1s 57ms/step - loss: 0.1135 - accuracy: 0.9583 - val_loss: 0.5849 - val_accuracy: 0.6222
# 6/6 [==============================] - 0s 7ms/step - loss: 0.5849 - accuracy: 0.6222
# Test accuracy: 0.6222222447395325
# INFO:tensorflow:Reloading Tuner from tuner_directory\writer_identification\tuner0.json
# INFO:tensorflow:Oracle triggered exit
# Epoch 1/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.6190 - accuracy: 0.67
# 23/23 [==============================] - 2s 60ms/step - loss: 0.6092 - accuracy: 0.6819 - val_loss: 0.9748 - val_accuracy: 0.4778
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step loss: 0.4031 - accuracy: 0.82
# 23/23 [==============================] - 1s 55ms/step - loss: 0.3980 - accuracy: 0.8306 - val_loss: 1.2635 - val_accuracy: 0.4778
# Epoch 3/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.3203 - accuracy: 0.85
# 23/23 [==============================] - 1s 55ms/step - loss: 0.3212 - accuracy: 0.8542 - val_loss: 0.7275 - val_accuracy: 0.4778
# Epoch 4/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.2744 - accuracy: 0.88
# 23/23 [==============================] - 1s 58ms/step - loss: 0.2728 - accuracy: 0.8875 - val_loss: 0.7661 - val_accuracy: 0.4778
# Epoch 5/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.2165 - accuracy: 0.90
# 23/23 [==============================] - 1s 56ms/step - loss: 0.2165 - accuracy: 0.9097 - val_loss: 0.6758 - val_accuracy: 0.4833
# Epoch 6/10
# 6/6 [==============================] - 0s 2ms/step loss: 0.1666 - accuracy: 0.93
# 23/23 [==============================] - 1s 56ms/step - loss: 0.1628 - accuracy: 0.9403 - val_loss: 0.9904 - val_accuracy: 0.4778
# Epoch 7/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.1612 - accuracy: 0.94
# 23/23 [==============================] - 1s 57ms/step - loss: 0.1591 - accuracy: 0.9431 - val_loss: 0.6262 - val_accuracy: 0.5667
# Epoch 8/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.1156 - accuracy: 0.96
# 23/23 [==============================] - 1s 56ms/step - loss: 0.1167 - accuracy: 0.9611 - val_loss: 0.6186 - val_accuracy: 0.5278
# Epoch 9/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.1099 - accuracy: 0.96
# 23/23 [==============================] - 1s 57ms/step - loss: 0.1126 - accuracy: 0.9639 - val_loss: 0.5440 - val_accuracy: 0.8111
# Epoch 10/10
# 6/6 [==============================] - 0s 3ms/step loss: 0.0699 - accuracy: 0.97
# 23/23 [==============================] - 1s 57ms/step - loss: 0.0751 - accuracy: 0.9750 - val_loss: 0.5327 - val_accuracy: 0.7111
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5327 - accuracy: 0.7111
# Test accuracy: 0.7111111283302307
# Best accuracy: 0.9111111164093018
# Best hyperparameters: {'conv_filters': 64, 'dense_units': 128}
# Best accuracy obtained from run number: 0.9111111164093018

# %% [markdown]
# ## Model Evaluation
# Evaluate the trained model with the best accuracy using test data.

# %%
# print(best_model[callbacks])
print("Best accuracy obtained from run number:", best_run_num)
# Out:
# Best accuracy obtained from run number: 1

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# %tensorboard --logdir logs/fit
# Clear any logs from previous runs
# %tensorboard --logdir=./visualizations
# Out:
#       <iframe id="tensorboard-frame-4deb740553a2507c" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4deb740553a2507c");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# Load the saved model with the highest validation accuracy
best_model = tf.keras.models.load_model('writerIdentifier_v5_model.h5')

# Evaluate the best model
loss, accuracy = best_model.evaluate(X_test, y_test)
print('Loss:', loss)
print('Test accuracy:', accuracy)
# Out:
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5662 - accuracy: 0.9111
# Loss: 0.5662302374839783
# Test accuracy: 0.9111111164093018
